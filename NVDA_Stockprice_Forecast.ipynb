# %% [markdown]
# ## NVIDIA (NVDA) Stock Price Prediction using Facebook Prophet

# %% [markdown]
# ## Import necessary libraries

# %%
# Import necessary libraries

import pandas as pd  ## Data manipulation
import plotly.express as px  ## data visulization - default mode is off
from prophet import Prophet ## Forecasting

# %%
# Initializing Plotly
import plotly.io as pio
pio.renderers.default='colab'

# %% [markdown]
# ##Import the Dataset and Explore
# - Using 1 year of NVDA stock price data since 28 Jul 2023.
# - Dataset is loaded from Yahoo finance

# %%
df = pd.read_csv("NVDA.csv")

# %%
df ## NVDA stock on 2023.07.28 - 2024.07.28
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-07-28   46.667999   47.027000   46.381001   46.750000   46.736008
# 1    2023-07-31   46.754002   47.130001   46.506001   46.729000   46.715012
# 2    2023-08-01   46.459999   46.900002   46.027000   46.507000   46.493080
# 3    2023-08-02   45.831001   45.840000   43.387001   44.269001   44.255753
# 4    2023-08-03   43.799999   45.118000   43.799999   44.514999   44.501678
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-07-22  120.349998  124.070000  119.860001  123.540001  123.540001
# 247  2024-07-23  122.779999  124.690002  122.099998  122.589996  122.589996
# 248  2024-07-24  119.169998  119.949997  113.440002  114.250000  114.250000
# 249  2024-07-25  113.040001  116.629997  106.300003  112.279999  112.279999
# 250  2024-07-26  116.190002  116.199997  111.580002  113.059998  113.059998
#
#         Volume
# 0    331194000
# 1    251055000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean    72.055789   73.289542   70.624371   72.035526   72.027642
# std     29.185290   29.755607   28.383494   29.071939   29.074566
# min     40.450001   40.879002   39.230000   40.326000   40.317253
# 25%     46.470999   47.090500   45.507999   46.611500   46.605486
# 50%     61.231998   62.488998   60.700001   61.527000   61.519058
# 75%     90.302002   91.577499   88.731499   90.385502   90.378078
# max    139.800003  140.759995  132.419998  135.580002  135.580002
#
#              Volume
# count  2.510000e+02
# mean   4.573149e+08
# std    1.535023e+08
# min    1.739110e+08
# 25%    3.678450e+08
# 50%    4.319290e+08
# 75%    5.234430e+08
# max    1.156044e+09

# %% [markdown]
# ##Data Visualization using plotly express - Visualizing the historical perfomance of Nvidia

# %%
# Line graph, Area graph, Box plot (Anlyzing price and volume)

# %%
px.area(df, x="Date", y="Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(df, x="Date", y="Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.area(df, x="Date", y="Volume")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df, y="Volume")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(df, y="Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Data Preparation for Prophet

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-07-28   46.667999   47.027000   46.381001   46.750000   46.736008
# 1    2023-07-31   46.754002   47.130001   46.506001   46.729000   46.715012
# 2    2023-08-01   46.459999   46.900002   46.027000   46.507000   46.493080
# 3    2023-08-02   45.831001   45.840000   43.387001   44.269001   44.255753
# 4    2023-08-03   43.799999   45.118000   43.799999   44.514999   44.501678
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-07-22  120.349998  124.070000  119.860001  123.540001  123.540001
# 247  2024-07-23  122.779999  124.690002  122.099998  122.589996  122.589996
# 248  2024-07-24  119.169998  119.949997  113.440002  114.250000  114.250000
# 249  2024-07-25  113.040001  116.629997  106.300003  112.279999  112.279999
# 250  2024-07-26  116.190002  116.199997  111.580002  113.059998  113.059998
#
#         Volume
# 0    331194000
# 1    251055000
# ...

# %%
columns=["Date", "Close"] ## Segregate 'Date' and 'Close' columns
ndf = pd.DataFrame(df, columns =columns) ## Create a new dataframe

# %%
ndf
# Out:
#            Date       Close
# 0    2023-07-28   46.750000
# 1    2023-07-31   46.729000
# 2    2023-08-01   46.507000
# 3    2023-08-02   44.269001
# 4    2023-08-03   44.514999
# ..          ...         ...
# 246  2024-07-22  123.540001
# 247  2024-07-23  122.589996
# 248  2024-07-24  114.250000
# 249  2024-07-25  112.279999
# 250  2024-07-26  113.059998
#
# [251 rows x 2 columns]

# %%
prophet_df = ndf.rename(columns={'Date':'ds', 'Close':'y'})

# %%
prophet_df
# Out:
#              ds           y
# 0    2023-07-28   46.750000
# 1    2023-07-31   46.729000
# 2    2023-08-01   46.507000
# 3    2023-08-02   44.269001
# 4    2023-08-03   44.514999
# ..          ...         ...
# 246  2024-07-22  123.540001
# 247  2024-07-23  122.589996
# 248  2024-07-24  114.250000
# 249  2024-07-25  112.279999
# 250  2024-07-26  113.059998
#
# [251 rows x 2 columns]

# %% [markdown]
# ### Creating Facebook Prophet Model

# %%
# Train the model
m = Prophet()
m.fit(prophet_df) ## Import data and fit the data into model
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj2bbbsrt/6tauiq8c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj2bbbsrt/kr07vl46.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46834', 'data', 'file=/tmp/tmpj2bbbsrt/6tauiq8c.json', 'init=/tmp/tmpj2bbbsrt/kr07vl46.json', 'output', 'file=/tmp/tmpj2bbbsrt/prophet_modelwwp6sn9h/prophet_model-20240728150327.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:03:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:03:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# ### Forecasting

# %%
future = m.make_future_dataframe(periods=30) ## Making a forecasted table for 30 days
forecast = m.predict(future) # Predict the model

# %%
forecast
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2023-07-28   43.980932   34.966539   50.854990    43.980932    43.980932
# 1   2023-07-31   44.047965   36.463053   52.598799    44.047965    44.047965
# 2   2023-08-01   44.070309   36.051972   51.832733    44.070309    44.070309
# 3   2023-08-02   44.092654   35.165545   50.900805    44.092654    44.092654
# 4   2023-08-03   44.114998   35.831654   51.563104    44.114998    44.114998
# ..         ...         ...         ...         ...          ...          ...
# 276 2024-08-21  141.886624  133.109136  148.804592   141.461978   142.408809
# 277 2024-08-22  142.284452  133.817300  149.429181   141.830186   142.830748
# 278 2024-08-23  142.682281  134.647767  150.302293   142.201522   143.254088
# 279 2024-08-24  143.080109  136.913954  152.834464   142.567410   143.691637
# 280 2024-08-25  143.477938  136.324774  153.125418   142.939512   144.112507
#
# ...

# %%
px.line(forecast, x='ds', y='yhat')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure = m.plot(forecast, xlabel='ds', ylabel='y')

# %%
figure2 = m.plot_components(forecast) ##Trends of component - weekyly lower, quarterly upper

# %% [markdown]
# ### Downloading the Forecast data

# %%
from google.colab import files
forecast.to_csv('Forecast.csv') ## pd function
files.download('Forecast.csv') ## Download the forecast.csv
